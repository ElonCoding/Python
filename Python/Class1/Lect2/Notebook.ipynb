# %% [markdown]
# # Welcome to your first Virtual notebook of Python. I hope you all also do this in yours VS Code.

# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["# Welcome to Jupyter Notebook\n", "This is a Python learning notebook."]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": ["print('Hello World')"]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.9.0"
  },
  "author": "Student",
  "title": "Python Learning Notebook"
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# {'cells': [], 'metadata': {}, 'nbformat': 4, 'nbformat_minor': 5}

# %%
print("hi\\nhello")
# Out:
# hi

# %%
name = input("Enter your name: ")
print("Hello " + name)
# Out:
# Hello Parikshit

# %%
name = input("Enter your name: ")
print("Hello " + name)
age = int(input("Enter your age: "))
print("You are " + str(age) + " years old.")
height = float(input("Enter your height in meters: "))
print("Nice to meet you " + name + "!" + " and you are " + str(height) + " meters tall.")
# Out:
# Hello Parikshit
# You are 20 years old.
# Nice to meet you Parikshit ! and you are 5.11 meters tall.

# %%
name = "John"
print(name)
# Out:
# John
