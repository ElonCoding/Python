# %%
#Wite a program to sum of 2 number
n = int(input("Enier a number: "))
m = int(input("Enier a number: "))
sum = n+m
print(sum)
# Out:
# 7

# %%
n = int(input("Enier a number: "))
m = int(input("Enier a number: "))
sub=n-m
print(sub)
# Out:
# -7

# %%
#write a program to m
